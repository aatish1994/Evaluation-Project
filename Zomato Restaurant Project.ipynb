# %% [markdown]
# **Problem Statement:
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#  Country code
#  Country name
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
# Problem statement : In this dataset predict 2 things –**
# 1) Average Cost for two
# 2) Price range

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading dataset
data1=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding="latin-1")

# %%
pd.set_option('display.max_columns',None)

# %%
data1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
#checking shape of data1
data1.shape
# Out:
# (9551, 21)

# %%
#loading data 2
data2=pd.read_excel('Country-Code.xlsx')
data2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#checking shape of the data2
data2.shape
# Out:
# (15, 2)

# %%
#merging both the dataset
data=pd.merge(data1,data2,on='Country Code',how='left')

# %%
#checking the overview of the dataset
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#checking the shape of the dataset
data.shape
# Out:
# (9551, 22)

# %% [markdown]
# **So we can see that there are 9551 columns and 22  rows in the dataset.**

# %%
#checking data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# **So in this we can see that there are 3 float data type columns, 5 integer data type columns and 14 object data type coluumns are there in the dataset.**

# %%
#checking for null values
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# **So in this we can see that there are no null values present in the dataset.**

# %%
#checking for duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **So we can see that there are no duplicates are present in the dataset.**

# %% [markdown]
# **Checking unique values**

# %%
#checking for unique values
data['Restaurant ID'].unique()
# Out:
# array([6317637, 6304287, 6300002, ..., 5915807, 5916112, 5927402],
#       dtype=int64)

# %% [markdown]
# **This columns gives us the information of Unique id of every restaurant across various cities of the world.**

# %%
#checking for unique values
data['Restaurant Name'].unique()
# Out:
# array(['Le Petit Souffle', 'Izakaya Kikufuji', 'Heat - Edsa Shangri-La',
#        ..., 'Huqqa', 'A\x81ô\x81ôk Kahve', "Walter's Coffee Roastery"],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about the Name of the restaurant.**

# %%
#checking for unique values
data['Country Code'].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %% [markdown]
# **This column gives us the information about the Country in which restaurant is located.**

# %%
#checking for unique values
data['City'].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Brasí_lia', 'Rio de Janeiro', 'Sí£o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %% [markdown]
# **This column gives us the information about the City in which restaurant is located.**

# %%
#checking for unique values
data['Address'].unique()
# Out:
# array(['Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City',
#        'Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City',
#        'Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City', ...,
#        'Kuruí_e\x81ôme Mahallesi, Muallim Naci Caddesi, No 56, Be\x81ôikta\x81ô, ÛÁstanbul',
#        'Kuruí_e\x81ôme Mahallesi, Muallim Naci Caddesi, No 64/B, Be\x81ôikta\x81ô, ÛÁstanbul',
#        'CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B, KadÛ±kí_y, ÛÁstanbul'],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about the Address of the restaurant.**

# %%
#checking for unique values
data['Locality'].unique()
# Out:
# array(['Century City Mall, Poblacion, Makati City',
#        'Little Tokyo, Legaspi Village, Makati City',
#        'Edsa Shangri-La, Ortigas, Mandaluyong City', ..., 'Ko\x81ôuyolu',
#        'Kuruí_e\x81ôme', 'Moda'], dtype=object)

# %% [markdown]
# **This column gives us the information about the Location in the city.**

# %%
#checking for unique values
data['Locality Verbose'].unique()
# Out:
# array(['Century City Mall, Poblacion, Makati City, Makati City',
#        'Little Tokyo, Legaspi Village, Makati City, Makati City',
#        'Edsa Shangri-La, Ortigas, Mandaluyong City, Mandaluyong City',
#        ..., 'Ko\x81ôuyolu, ÛÁstanbul', 'Kuruí_e\x81ôme, ÛÁstanbul',
#        'Moda, ÛÁstanbul'], dtype=object)

# %% [markdown]
# **This column gives us the information about the Detailed description of the locality.**

# %%
#checking for unique values
data['Longitude'].unique()
# Out:
# array([121.027535  , 121.014101  , 121.056831  , ...,  29.03464001,
#         29.036019  ,  29.02601603])

# %% [markdown]
# **This column gives us the information about the Longitude coordinate of the restaurant.**

# %%
#checking for unique values
data['Latitude'].unique()
# Out:
# array([14.565443  , 14.553708  , 14.581404  , ..., 41.05581715,
#        41.057979  , 40.98477563])

# %% [markdown]
# **This column gives us the information about the Latitude coordinate of the restaurant.**

# %%
#checking for unique values
data['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about the  Cuisines offered by the restaurant.**

# %%
#checking for unique values
data['Average Cost for two'].unique()
# Out:
# array([  1100,   1200,   4000,   1500,   1000,   2000,   6000,    800,
#           900,    700,    850,    600,   3000,   1800,     55,     30,
#            45,     60,     50,     80,     90,    200,    150,    100,
#           230,    240,    350,    140,    170,    120,    250,     40,
#            70,    300,     85,     75,    400,     65,     25,     10,
#             0,     20,     35,      7,    270,    500,    430,    315,
#           220,     95,    190,    260,    180,    330,    280,    160,
#           285,    130,    110,   2500,   3600,    550,   1400,    450,
#           950,    650,   1300,   2400,   1600,   2200,    750,   1700,
#          1250,   1900,   2700,   3500,   5000,   2300,   1750,   3200,
#          2100,   1850,   4500,   3300,   1350,   1650,   1950,   1050,
#           290,   1450,   2800,   3650,   4800,   1550,    720,   6500,
#          7000,   1150,   2900,   2600,   4700,   3700,   3800,   4100,
# ...

# %% [markdown]
# **This column gives us the information about the Cost for two people in different currencies.**

# %%
#checking for unique values
data['Currency'].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(\x8c£)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %% [markdown]
# **This column gives us the information about the Currency of the country.**

# %%
#checking for unique values
data['Has Table booking'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **This column gives us the information about whether the table is booker or not.**

# %%
#checking for unique values
data['Has Online delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# **This column gives us the information about whether restaurant has online delivery or not.**

# %%
#checking for unique values
data['Is delivering now'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# **This column gives us the information about whether restaurant is delivering now or not.**

# %%
#checking for unique values
data['Switch to order menu'].unique()
# Out:
# array(['No'], dtype=object)

# %% [markdown]
# **This column gives us the information about menu that we can switch to order menu or not.**

# %%
#checking for unique values
data['Price range'].unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %% [markdown]
# **This column gives us the information about the range of price of food.**

# %%
#checking for unique values
data['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %% [markdown]
# **This column gives us the information about the Average rating out of 5.**

# %%
#checking for unique values
data['Rating color'].unique()
# Out:
# array(['Dark Green', 'Green', 'Yellow', 'Orange', 'White', 'Red'],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about depending upon the average rating color.**

# %%
#checking for unique values
data['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about text on the basis of rating of rating.**

# %%
#checking for unique values
data['Votes'].unique()
# Out:
# array([ 314,  591,  270, ...,  788, 1034,  901], dtype=int64)

# %% [markdown]
# **This column gives us the information about Number of ratings casted by people.**

# %%
#checking for unique values
data['Country'].unique()
# Out:
# array(['Phillipines', 'Brazil', 'United States', 'Australia', 'Canada',
#        'Singapore', 'UAE', 'India', 'Indonesia', 'New Zealand',
#        'United Kingdom', 'Qatar', 'South Africa', 'Sri Lanka', 'Turkey'],
#       dtype=object)

# %% [markdown]
# **This column gives us the information about the names of the countries.**

# %%
#checking for number of unique values
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# **So we can see the numnber of unique values present in the dataset.**

# %%
#plotting count plot
sns.countplot(x='Country Code',data=data)
plt.show()

# %% [markdown]
# **By looking at the plot we can see that most of the restaurants which are tied with zomato are located in country having country code as 1.**

# %%
#checking which country have the country code 1
data[data['Country Code']==1][['Country','Country Code']]
# Out:
#      Country  Country Code
# 624    India             1
# 625    India             1
# 626    India             1
# 627    India             1
# 628    India             1
# ...      ...           ...
# 9271   India             1
# 9272   India             1
# 9273   India             1
# 9274   India             1
# 9275   India             1
#
# [8652 rows x 2 columns]

# %% [markdown]
# **so we can see that country bearing country code 1 is India.so we can say that most of the restaurants which are tied with zomato are located in India.**

# %%
#plotting count plot
plt.figure(figsize=(20,15))
sns.countplot(x='City',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that most of the restaurants which are tied with zomato are located in the city New Delhi.**

# %%
#plotting count plot
plt.figure(figsize=(20,15))
sns.countplot(x='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that average cost for the two which is reported most of the times is 500 and followed by 300.**

# %%
#plotting count plot
plt.figure(figsize=(20,15))
sns.countplot(x='Currency',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that as most of the restauarants which are tied zomato are located in India,so most of the restaurants accept Indian rupees(Rs) that is the currency of India.**

# %%
#plotting count plot
sns.countplot(x='Has Table booking',data=data)
plt.show()

# %% [markdown]
# **By looking at the plot we can see that zomato tied restaurants in most cases does not  provide with table bookings in advance.May be zomato have not been able to crack the deal with some of the restauransts to avail advance booking,though so-me of the zomato tied restauransts are providing with advance booking which is very less as compared to the ones which are not providing**

# %%
#plotting count plot
sns.countplot(x='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the restaurants which are tied with zomato does not provide online delivery.**

# %%
#plotting count plot
sns.countplot(x='Is delivering now',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the restaurants tied with zomato does not provide with service that is delivering now.**

# %%
#plotting count plot
sns.countplot(x='Switch to order menu',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the zomato partnered restaurants does provide the service of switch to order menu.**

# %%
#plotting count plot
sns.countplot(x='Price range',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the range of the price of the food is 1, and we can see that as the price range increases the count decreases.**

# %%
#plotting count plot
sns.countplot(x='Aggregate rating',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this we can see that most of the customers have given 0.0 as the highest aggregate rating followed by 3.2 and 3.1.**

# %%
#plotting count plot
sns.countplot(x='Rating color',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that most of the people have used orange color for rating followed by white.**

# %%
#plotting count plot
sns.countplot(x='Rating text',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that most of the people have used Average as rating text.Some of the people have not rated only.Around 2000 people have used good as rating text and very few people have given poor as rating text.**

# %%
#plotting count plot
sns.countplot(x='Country',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that most of the restaurants that are tied with zomato are from India followed by United states.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Country Code',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see thet country having country code 94 is having the highest avarage cost for two people.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='City',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that Tangerang city has the highest average cost for the two.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Currency',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that country code 94 belongs to the country Indonesia as we can see in this plot as when when the average cost for the two excceds 50000, most of the times Indonesian Rupian(DR) is used.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Has Table booking',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when the average cost for the exceeds 1200 we can see that most of the times they were provived with advance table booking.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Has Online delivery',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when the average cost for the two exceeds 750 online delivery have not been provided that means that they have come to the restaurants physically to have food.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Price range',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when the range of price of food is 3 the average cost for the two is the highest that is above 5000 and when the range of price of food is 1 than the average cost for the two is below 1000.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Aggregate rating',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when there is a highest average cost for two person is there that time 4.9 aggregate rating is being given by the customers.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Rating color',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when there is a highest average cost for two person is there that time Dark green have been used as rating colot.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Rating text',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that when there is a highest average cost for two person is there that time Excellent rating text have been used.**

# %%
#plotting barplot
plt.figure(figsize=(20,15))
sns.barplot(x='Country',y='Average Cost for two',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that in country Indonesia highest average cost for two person is there.**

# %%
#CHECKING THE TOP 10 RESTAURANTS WHO ARE HAVING HIGHEST AVERAGE COST FOR THE TWO
df=data.sort_values(by='Average Cost for two',ascending=False)[:10]

# %%
df
# Out:
#       Restaurant ID              Restaurant Name  Country Code       City  \
# 9284        7410290     Satoo - Hotel Shangri-La            94    Jakarta
# 9283        7402935                         Skye            94    Jakarta
# 9287        7420899                   Sushi Masa            94    Jakarta
# 9289        7421967               3 Wise Monkeys            94    Jakarta
# 9294        7422489  Avec Moi Restaurant and Bar            94    Jakarta
# 9295       18386856                      Onokabe            94  Tangerang
# 9288       18352452   Lucky Cat Coffee & Kitchen            94    Jakarta
# 9278        7423482                   Lemongrass            94      Bogor
# 9285       18391256                        MONKS            94    Jakarta
# 9296        7417450             Talaga Sampireun            94  Tangerang
#
#                                                 Address  \
# 9284               Hotel Shangri-La, Jl. Jend. Sudirman
# ...

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see the top 10 restaurants as per to the highest average cost ofr the two,so highest  average cost ofr the two is 800000 and the restaurant name is satoo-Hotel Shangri-La and skye.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',hue='Country Code',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **So we can see that all this hotels with highest average cost for the two having code as 94.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',hue='Country',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that all this restaurants are from country Indonesia.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',hue='City',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that most of this restaurants with highest average cost for the two are from city Jakarta, two are from Tangerang and one is from Bogor.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',hue='Price range',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that most of this restaurants with highest average cost for the two are having price range 3.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Average Cost for two',hue='Rating text',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **By looking at the plot we can see that most of this restaurants with highest average cost for the two are having rating text as very good.**

# %%
#CHECKING THE TOP 5 RESTAURANTS WHERE AGGREGRATE RATINGS GIVEN BY THE CUSTOMERS IS HIGHEST
df1=data.sort_values(by='Aggregate rating',ascending=False)[:5]
df1
# Out:
#       Restaurant ID                Restaurant Name  Country Code       City  \
# 1381       18384115                    Caterspoint             1    Gurgaon
# 589        18269368        AB's Absolute Barbecues           214      Dubai
# 374        17580142  McGuire's Irish Pub & Brewery           216  Pensacola
# 9303       18217279                          Miann           148   Auckland
# 9299        7001086                          Milse           148   Auckland
#
#                                                 Address  \
# 1381                      S-27/11, DLF Phase 3, Gurgaon
# 589   Mezzanaine Floor, Centurion Star Tower, Deira ...
# 374           600 E Gregory Street, Pensacola, FL 32502
# 9303              57 Fort Street, Auckland Auckland CBD
# 9299  The Pavilions, 27 Tyler Street, Britomart, Auc...
#
#                     Locality               Locality Verbose   Longitude  \
# 1381             DLF Phase 3           DLF Phase 3, Gurgaon   77.103974
# ...

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see the top 5 restaurants with highest aggregate ratings, they are caterspoint,AB'S Absolute Barbecues, Mcguire's Irish Pub and Brewery,Miann and Milse.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Country Code',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that two restaurants are having 148 as country code, restaurant three restaurants are having 1,214 and 216 as country code.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='City',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that two restaurants are from the city Auckland,one from Gurgaon,one from Dubai and one from pensacola.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Average Cost for two',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that average cost for the two for restaurant caterspoint is 500,for AB'S Absolute Barbecues is 160,for  Mcguire's Irish Pub and Brewery is 40,for Miann is 25 and for Milse is 50.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Currency',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see the currency used in  restaurant caterspoint is Indian Rupees(Rs),for AB'S Absolute Barbecues is Deeram(AED),for Mcguire's Irish Pub and Brewery is Dollars,for Miann and for Milse is Newzealand($).**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Price range',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that price range for restaurant caterspoint is 2,for AB'S Absolute Barbecues is 3,for Mcguire's Irish Pub and Brewery is 3,for Miann is 1 and for Milse is 3.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Rating text',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that all the top 5 restaurants have rating text as Excellent.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Aggregate rating',hue='Country',data=df1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restaurant caterspoint is from country India, AB'S Absolute Barbecues is from UAE, Mcguire's Irish Pub and Brewery is from United States, Miann and Milse both are from Newzealand.**

# %%
#CHECKING THE TOP 5 RESTAURANTS WHERE Votings GIVEN BY THE CUSTOMERS IS HIGHEST
df2=data.sort_values(by='Votes',ascending=False)[:5]
df2
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 728           51705                       Toit             1  Bangalore
# 735           51040                   Truffles             1  Bangalore
# 3994         308322           Hauz Khas Social             1  New Delhi
# 2412          20404                  Peter Cat             1    Kolkata
# 739           56618  AB's - Absolute Barbecues             1  Bangalore
#
#                                                 Address  \
# 728   298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 735   28, 4th 'B' Cross, Koramangala 5th Block, Bang...
# 3994             9-A & 12, Hauz Khas Village, New Delhi
# 2412        18A, Park Street, Park Street Area, Kolkata
# 739   90/4, 3rd Floor, Outer Ring Road, Munnekollaly...
#
#                    Locality                  Locality Verbose  Longitude  \
# 728             Indiranagar            Indiranagar, Bangalore  77.640709
# ...

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **I  this plot we can see the top 5 restaurants as per to the votigs given by the customers.They are Toit,Truffles,Hauz Khas Social, peter cat and AB's-Absolute Barbecues.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Country Code',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that all this top 5 restaurant have country code that is 1.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='City',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restaurants Toit, truffles and AB's are from the city Bangalore.Hauz khas social is from the city New Delhi and Peter cat is from Kolkata.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Average Cost for two',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restaurants Toit have average cost price for two is 2000, for truffles average cost price for two is 800 for AB's average cost price for two is 1400 ,for Hauz khas social average cost price for two is 1600 and for Peter cataverage cost price for two is 1000.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Currency',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that all this top 5 restaurant accept the currencies of Indian rupees that means all this restaurants are from India.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Price range',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restaurant Hauz khas social,peter cat and AB'S got 3 as price range, toit got 4 as price range and truffles got 2 as price range.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Aggregate rating',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restuarant toit have got the highest aggregate rating that is 4.8.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Rating text',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that restaurant Toit,truffles and AB'S got excellent and rating text and Hauz khas scocial and peter cat got very good rating text.**

# %%
#plotting bar plot
plt.figure(figsize=(20,15))
sns.barplot(x='Restaurant Name',y='Votes',hue='Country',data=df2)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **In this plot we can see that all this top 5 restaurants are from India.**

# %%
#checking in which country zomato tied restaurants have online delivery
a=data[data['Has Online delivery']=='Yes'][['Country','Has Online delivery']]
a
# Out:
#      Country Has Online delivery
# 565      UAE                 Yes
# 566      UAE                 Yes
# 571      UAE                 Yes
# 572      UAE                 Yes
# 573      UAE                 Yes
# ...      ...                 ...
# 9166   India                 Yes
# 9168   India                 Yes
# 9170   India                 Yes
# 9171   India                 Yes
# 9194   India                 Yes
#
# [2451 rows x 2 columns]

# %%
a.value_counts()
# Out:
# Country  Has Online delivery
# India    Yes                    2423
# UAE      Yes                      28
# dtype: int64

# %%
#plotting pie plot
plt.figure(figsize=(8,8))
labels='India','UAE'
plt.pie(x=a.value_counts(),labels=labels,autopct='%.2f')
lt.show()

# %% [markdown]
# **In this plot we can see that in India 98.86% online delivery is available and in UAE only 1.14%.**

# %%
#checking for which city in india is doing more business with zomato
b=data[data['Country']=='India']['City'].value_counts()[:5]
b
# Out:
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: City, dtype: int64

# %%
#plotting pie plot
plt.figure(figsize=(8,8))
plt.pie(x=b,labels=b.index,autopct='%.2f')
plt.show()

# %% [markdown]
# **In this plot we can see that most of the restuarants which are tied with zomato are from the city New Delhi followed by Gurgaon,Noida,Fariabad and Ghaziabad.**

# %%
#checking about the top 10 cuisines liked by people according to rating text
c=data[data['Rating text']=='Excellent']['Cuisines'].value_counts()[:10]
c
# Out:
# Cafe                     8
# North Indian             7
# Italian                  7
# Indian                   5
# Ice Cream                5
# Seafood                  5
# Desserts                 4
# Asian                    4
# North Indian, Mughlai    4
# Modern Indian            3
# Name: Cuisines, dtype: int64

# %%
#plotting pie plot
plt.figure(figsize=(8,8))
plt.pie(x=c,labels=c.index,autopct='%.2f')
plt.show()

# %% [markdown]
# **In this plot we can see that most of people have liked cafe, followed by North indian and italian cuisines.**

# %%
data=data.drop(['Country Code','Locality Verbose','Restaurant ID','Is delivering now','Has Table booking','Switch to order menu','Has Online delivery','Country','Locality'],axis=1)
data
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546              NamlÛ± Gurme         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548                     Huqqa         ÛÁstanbul
# 9549              Aôôk Kahve         ÛÁstanbul
# 9550  Walter's Coffee Roastery         ÛÁstanbul
#
#                                                 Address   Longitude  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...  121.027535
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...  121.014101
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...  121.056831
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...  121.056475
# ...

# %% [markdown]
# **so we can see that the columns have been dropped, i have dropped this columns as i find it irrelevent at the time of prediction.**

# %%
#Importing required libraries
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding column
lab_enc=LabelEncoder()
df1=lab_enc.fit_transform(data['Restaurant Name'])
df2=lab_enc.fit_transform(data['City'])
df3=lab_enc.fit_transform(data['Address'])
df4=lab_enc.fit_transform(data['Cuisines'])
df5=lab_enc.fit_transform(data['Currency'])
df6=lab_enc.fit_transform(data['Rating color'])
df7=lab_enc.fit_transform(data['Rating text'])

# %%
#Transfering the data 
data['Restaurant Name']=df1
data['City']=df2
data['Address']=df3
data['Cuisines']=df4
data['Currency']=df5
data['Rating color']=df6
data['Rating text']=df7

# %%
#Checking whether the data is encoded or not
data.head()
# Out:
#    Restaurant Name  City  Address   Longitude   Latitude  Cuisines  \
# 0             3749    73     8685  121.027535  14.565443       920
# 1             3173    73     6055  121.014101  14.553708      1111
# 2             2897    75     4684  121.056831  14.581404      1671
# 3             4707    75     8690  121.056475  14.585318      1126
# 4             5523    75     8689  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Price range  Aggregate rating  \
# 0                  1100         0            3               4.8
# 1                  1200         0            3               4.5
# 2                  4000         0            4               4.4
# 3                  1500         0            4               4.9
# 4                  1500         0            4               4.8
#
#    Rating color  Rating text  Votes
# 0             0            1    314
# 1             0            1    591
# 2             1            5    270
# ...

# %% [markdown]
# **So we can see that categorical columns have been encoded.**

# %%
#Checking for correlation
data.drop(['Average Cost for two'],axis=1).corrwith(data['Average Cost for two']).plot(kind='bar',grid=True,figsize=(20,10),title='Correlation with Average Cost for two')
plt.show()

# %% [markdown]
# **In this plot we can see that lattitude is very highly negatively correlated to the label followed by price range and votes.Least correlated are cuisines**

# %%
#Plotting heatmap
corr=data.corr().abs()
plt.figure(figsize=(25,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# **Observation**
#
# * **In this i am considering a percenatage of 75% between the features so that they are called as multicorrelated.**
# * **So in this heatmap i dont find any feature multicorrelated to each other.**

# %%
#making dataset of continuous data 
df4=data[['Longitude','Latitude','Aggregate rating','Votes']]
df4
# Out:
#        Longitude   Latitude  Aggregate rating  Votes
# 0     121.027535  14.565443               4.8    314
# 1     121.014101  14.553708               4.5    591
# 2     121.056831  14.581404               4.4    270
# 3     121.056475  14.585318               4.9    365
# 4     121.057508  14.584450               4.8    229
# ...          ...        ...               ...    ...
# 9546   28.977392  41.022793               4.1    788
# 9547   29.041297  41.009847               4.2   1034
# 9548   29.034640  41.055817               3.7    661
# 9549   29.036019  41.057979               4.0    901
# 9550   29.026016  40.984776               4.0    591
#
# [9551 rows x 4 columns]

# %%
#plotting box plot
plt.figure(figsize=(5,40))
plotnumber=1
for column in df4:
    if plotnumber<=4:
        ax=plt.subplot(5,1,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **By looking at the plot we can see that price range and votes column have the outliers. so using z-score method to remove the outliers.**

# %%
#Importing required libraries
from scipy.stats import zscore

# %%
#Removing outliers
z_score=zscore(data[['Longitude','Latitude','Aggregate rating','Votes']])
abs_z_score=np.abs(z_score)
threshold=3
z=(abs_z_score<3).all(axis=1)

# %%
data[z].shape
# Out:
# (8772, 13)

# %%
#Percentage Loss of Data
data_loss=((9551-8772)/9551)*100
print(f'Data Loss:{data_loss} %')
# Out:
# Data Loss:8.156214009004293 %

# %% [markdown]
# **Data loss is more than 7%,so not removing outliers.**

# %%
#checking skewness for continuous columns
data.skew()
# Out:
# Restaurant Name          0.044637
# City                    -1.193777
# Address                 -0.040407
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# **In this we can see that lattitude,longitude,aggregate rating and votes have skewness so using power transform method to treat the skewness.**

# %%
#Importing required libraries
from sklearn.preprocessing import power_transform

# %%
#using power transform method
data[['Longitude','Latitude','Aggregate rating','Votes']]=power_transform(data[['Longitude','Latitude','Aggregate rating','Votes']],method='yeo-johnson')
data[['Longitude','Latitude','Aggregate rating','Votes']]
# Out:
#       Longitude  Latitude  Aggregate rating     Votes
# 0      2.498033 -1.602771          1.833264  1.191885
# 1      2.497306 -1.603989          1.506121  1.507786
# 2      2.499617 -1.601115          1.400030  1.116765
# 3      2.499598 -1.600709          1.945248  1.266889
# 4      2.499653 -1.600799          1.833264  1.034953
# ...         ...       ...               ...       ...
# 9546  -1.640540  2.270905          1.090715  1.652086
# 9547  -1.638445  2.268528          1.192320  1.788687
# 9548  -1.638664  2.276969          0.699460  1.563891
# 9549  -1.638619  2.277366          0.990620  1.719424
# 9550  -1.638946  2.263927          0.990620  1.507786
#
# [9551 rows x 4 columns]

# %%
#checking skewness
data.skew()
# Out:
# Restaurant Name          0.044637
# City                    -1.193777
# Address                 -0.040407
# Longitude               -0.803832
# Latitude                -0.293200
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Price range              0.889618
# Aggregate rating        -0.610806
# Rating color             0.046009
# Rating text              0.431408
# Votes                   -0.004029
# dtype: float64

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['Average Cost for two'],axis=1)
#Label
y=data['Average Cost for two']

# %%
#Standardiziing the data
#Importing require libraries
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
x_scaler=Scaler.fit_transform(x)
x_scaler
# Out:
# array([[ 0.0447056 , -0.22853276,  1.61466656, ..., -1.97785894,
#         -0.4654417 ,  1.1918848 ],
#        [-0.22410085, -0.22853276,  0.5895583 , ..., -1.97785894,
#         -0.4654417 ,  1.5077858 ],
#        [-0.35290395, -0.14231731,  0.05517677, ..., -1.30805322,
#          1.89507002,  1.11676465],
#        ...,
#        [-0.27263535,  2.65968456,  0.55486833, ...,  1.37116966,
#          0.12468623,  1.5638909 ],
#        [-1.46546399,  2.65968456,  0.5552581 , ..., -1.30805322,
#          1.89507002,  1.719424  ],
#        [ 1.67387805,  2.65968456, -0.11086738, ..., -1.30805322,
#          1.89507002,  1.5077858 ]])

# %%
x_scaler.shape
# Out:
# (9551, 12)

# %%
#Importing require libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaler,i)for i in range(x_scaler.shape[1])]
vif['feature']=x.columns
vif
# Out:
#          vif           feature
# 0   1.007132   Restaurant Name
# 1   1.063837              City
# 2   1.067150           Address
# 3   1.086898         Longitude
# 4   1.044181          Latitude
# 5   1.035406          Cuisines
# 6   1.048655          Currency
# 7   1.489068       Price range
# 8   4.712167  Aggregate rating
# 9   1.211327      Rating color
# 10  1.188601       Rating text
# 11  4.644608             Votes

# %% [markdown]
# **So we can see that there is not single value which is more than 5,so there is no multicollinearity problem**

# %% [markdown]
# **Using feature selection method.**

# %%
#importing required libraries
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features=SelectKBest(score_func=f_classif,k=11)
fit=best_features.fit(x,y)
data_scores=pd.DataFrame(fit.scores_)
data_columns=pd.DataFrame(x.columns)
feature_scores=pd.concat([data_columns,data_scores],axis=1)
feature_scores.columns=['Feature_Name','Score']
print(feature_scores.nlargest(11,'Score'))
# Out:
#         Feature_Name       Score
# 7        Price range  399.678183
# 11             Votes   38.952588
# 3          Longitude   38.395709
# 6           Currency   27.227608
# 8   Aggregate rating   25.569652
# 4           Latitude   15.910177
# 2            Address    7.298598
# 10       Rating text    6.980009
# 1               City    4.549936
# 9       Rating color    4.282917
# 5           Cuisines    3.651512

# %%
#making new dataset
new_feature=data[['Price range','Currency','Latitude','Aggregate rating','Votes','Longitude','Rating text','City','Rating color','Address','Cuisines']]
new_feature
# Out:
#       Price range  Currency  Latitude  Aggregate rating     Votes  Longitude  \
# 0               3         0 -1.602771          1.833264  1.191885   2.498033
# 1               3         0 -1.603989          1.506121  1.507786   2.497306
# 2               4         0 -1.601115          1.400030  1.116765   2.499617
# 3               4         0 -1.600709          1.945248  1.266889   2.499598
# 4               4         0 -1.600799          1.833264  1.034953   2.499653
# ...           ...       ...       ...               ...       ...        ...
# 9546            3        11  2.270905          1.090715  1.652086  -1.640540
# 9547            3        11  2.268528          1.192320  1.788687  -1.638445
# 9548            4        11  2.276969          0.699460  1.563891  -1.638664
# 9549            4        11  2.277366          0.990620  1.719424  -1.638619
# 9550            2        11  2.263927          0.990620  1.507786  -1.638946
#
# ...

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# **Xtreme Gradient Regressor**

# %%
xgb=xgb.XGBRegressor()

# %%
#using range fucntion to find the best random state using Logestic regression
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(new_feature,y,test_size=0.25,random_state=i)
    xgb.fit(x_train,y_train)
    pred=xgb.predict(x_train)
    y_pred=xgb.predict(x_test)
    print(f'at random state {i}, training accuracy is {metrics.r2_score(y_train,pred)*100}')
    print(f'at random state {i}, testing accuracy is {metrics.r2_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state 0, training accuracy is 99.9940263244263
# at random state 0, testing accuracy is 44.30550823529057
#
#
# at random state 1, training accuracy is 99.99642286740908
# at random state 1, testing accuracy is 67.19478992747815
#
#
# at random state 2, training accuracy is 99.99733952588838
# at random state 2, testing accuracy is -20.97466895003466
#
#
# at random state 3, training accuracy is 99.99761962169235
# at random state 3, testing accuracy is -162.3441407982889
#
#
# at random state 4, training accuracy is 99.99752342064806
# at random state 4, testing accuracy is -174.89625246052475
#
#
# at random state 5, training accuracy is 99.99685456850194
# at random state 5, testing accuracy is 25.05496462298784
#
#
# at random state 6, training accuracy is 99.99611368216557
# at random state 6, testing accuracy is 46.5310769097392
#
#
# at random state 7, training accuracy is 99.99719693436808
# at random state 7, testing accuracy is -3.8381937890383355
#
#
# ...

# %% [markdown]
# **Taking random state=61**

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(new_feature,y,test_size=0.25,random_state=61)

# %%
#Training the Model
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
pred=xgb.predict(x_train)
y_pred=xgb.predict(x_test)

# %%
#Printing the training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.99736812357116
#
#  Testing Score: 99.53346550883153

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for Gradient Boosting
for j in range(2,6):
    cv_score=cross_val_score(xgb,new_feature,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is -1209.7732692394632and accuracy for the testing is 0.9953346550883152
#
#
# at cross fold 3 the cv score is -1183.0440145352125and accuracy for the testing is 0.9953346550883152
#
#
# at cross fold 4 the cv score is -1222.75362675968and accuracy for the testing is 0.9953346550883152
#
#
# at cross fold 5 the cv score is -1013.8482623318005and accuracy for the testing is 0.9953346550883152

# %%
#mean absolute error
mean_absolute_error(y_test,y_pred)
# Out:
# 200.7570756496222

# %%
#mean squared error
mean_squared_error(y_test,y_pred)
# Out:
# 7663449.954485524

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 2768.293690070749

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **Gradient Boosting**

# %%
#Instantiating Gradient Boosting
gb=GradientBoostingRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(new_feature,y,test_size=0.25,random_state=61)

# %%
#Training the Model
gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred=gb.predict(x_train)
y_pred=gb.predict(x_test)

# %%
#Printing Training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.88476816998497
#
#  Testing score: 76.74529019642857

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for XGBoost
cv_score=cross_val_score(gb,new_feature,y,cv=5).mean()
cv_score
# Out:
# -955.4192170128784

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 248.44564170886323

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 11429441.294816189

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3380.745671418687

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **Ada Boost**

# %%
#Instantiating Ada Boost Regressor
ada=AdaBoostRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(new_feature,y,test_size=0.25,random_state=61)

# %%
#Training the data
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
pred=ada.predict(x_train)
y_pred=ada.predict(x_test)

# %%
#Printing Training and Testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 88.03851919403199
#
#  Testing Score: 40.474819876079714

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for XGBoost
cv_score=cross_val_score(ada,new_feature,y,cv=5).mean()
cv_score
# Out:
# -630.4857185663964

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 1354.8937524381286

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 29255989.75589971

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5408.880637978593

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **Random Forest Classifier**

# %%
#Instantiating XGBoost
rf=RandomForestRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(new_feature,y,test_size=0.25,random_state=61)

# %%
#Training data
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred=rf.predict(x_train)
y_pred=rf.predict(x_test)

# %%
#Printing Training and Testing Score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 92.34353133049058
#
#  Testing Score: 91.34204590154641

# %%
#Checking cross validation score for XGBoost
cv_score=cross_val_score(rf,new_feature,y,cv=5).mean()
cv_score
# Out:
# -1965.9512070249718

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 185.18823701842547

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 4255291.893012186

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 2062.8358861073234

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['XGBoost','Gradient Boosting','Ada Boost','Random forest'],
    'Training Score':[99.99,99.88,88.03,92.34],
    'Testing Score':[99.53,76.74,40.47,91.34]
})
data
# Out:
#               Models  Training Score  Testing Score
# 0            XGBoost           99.99          99.53
# 1  Gradient Boosting           99.88          76.74
# 2          Ada Boost           88.03          40.47
# 3      Random forest           92.34          91.34

# %% [markdown]
# **Observation**
# * **In this we can see thatXGB have seen most of the data that is 99.99% and also have the highest testing score that is 99.53% which is very good in relation to the prediction that is why i am going forward with Random XGB.**

# %%
#Using Grid Search cv for hyperparameter tuning for Gradient Boosting
from sklearn.model_selection import GridSearchCV

# %%
param_grid=({
    'n_estimators': [100,200],
    'max_depth' : [2,3,4],
    'eta':[0.3,0.1,0.01],
    'subsample':[0.1,0.2,0.3],
    'colsample_bytree' :[0.4,0.5,0.6]
})

# %%
grid_search=GridSearchCV(xgb,param_grid=param_grid,cv=5)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     callbacks=None, colsample_bylevel=1,
#                                     colsample_bynode=1, colsample_bytree=1,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=0, gpu_id=-1, grow_policy='depthwise',
#                                     importance_type=None,
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_bin=256,
#                                     max_cat...ot=4, max_delta_step=0,
#                                     max_depth=6, max_leaves=0,
#                                     min_child_weight=1, missing=nan,
#                                     monotone_constraints='()', n_estimators=100,
# ...

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.6,
#  'eta': 0.3,
#  'max_depth': 4,
#  'n_estimators': 100,
#  'subsample': 0.2}

# %%
#Training with the best parameters
xgb1=xgb.XGBRegressor(colsample_bytree=0.6,eta=0.3,max_depth=4,n_estimators=100,subsample=0.2)
xgb1.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.3,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
#Printing the training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.99736812357116
#
#  Testing Score: 99.53346550883153

# %% [markdown]
# **So we can see that by using hyperparameter tuning the training and testing score remained same.so i will save the model on which hyperparameter tuning was done as this model is tuned and will perform better.**

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(rf,open('Zomato Restaurant Regressor project','wb'))

# %% [markdown]
# **Prediction for Price Range**
#
# * **As we have already done EDA so i wont be doing the eda part and visualization part.**
#
# * **Further i will drop columns Restaurant ID,Locality Verbose,Country Code,Country and Switch to order menu.**
#
# * **I will encode categorical data columns.**
#
# * **Further i will check for skewnees again and remove it by using power transform method.**
#
# * **Again will check for outliers.**
#
# * **Will check for multicollinearity and will take further steps.**

# %%
# dataset 1
data1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#dataset 2
data2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#merging both the dataset
data=pd.merge(data1,data2,on='Country Code',how='left')

# %%
#checking overview of the dataset
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#dropping unwanted columns
data=data.drop(['Restaurant ID','Locality Verbose','Country Code','Country','Switch to order menu'],axis=1)
data.head()
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality   Longitude   Latitude  \
# 0   Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City  121.056831  14.581404
# 3      SM Megamall, Ortigas, Mandaluyong City  121.056475  14.585318
# ...

# %%
#encoding the categorical columns
#Encoding column
lab_enc=LabelEncoder()
df1=lab_enc.fit_transform(data['Restaurant Name'])
df2=lab_enc.fit_transform(data['City'])
df3=lab_enc.fit_transform(data['Address'])
df4=lab_enc.fit_transform(data['Locality'])
df5=lab_enc.fit_transform(data['Cuisines'])
df6=lab_enc.fit_transform(data['Currency'])
df7=lab_enc.fit_transform(data['Has Table booking'])
df8=lab_enc.fit_transform(data['Has Online delivery'])
df9=lab_enc.fit_transform(data['Is delivering now'])
df10=lab_enc.fit_transform(data['Rating color'])
df11=lab_enc.fit_transform(data['Rating text'])

# %%
#Transfering the data 
data['Restaurant Name']=df1
data['City']=df2
data['Address']=df3
data['Locality']=df4
data['Cuisines']=df5
data['Currency']=df6
data['Has Table booking']=df7
data['Has Online delivery']=df8
data['Is delivering now']=df9
data['Rating color']=df10
data['Rating text']=df11

# %%
data.head()
# Out:
#    Restaurant Name  City  Address  Locality   Longitude   Latitude  Cuisines  \
# 0             3749    73     8685       171  121.027535  14.565443       920
# 1             3173    73     6055       593  121.014101  14.553708      1111
# 2             2897    75     4684       308  121.056831  14.581404      1671
# 3             4707    75     8690       862  121.056475  14.585318      1126
# 4             5523    75     8689       862  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                  1100         0                  1                    0
# 1                  1200         0                  1                    0
# 2                  4000         0                  1                    0
# 3                  1500         0                  0                    0
# 4                  1500         0                  1                    0
#
# ...

# %% [markdown]
# **we can see that all the categorical columns have been encoded.**

# %%
#Checking correlation
data.drop(['Price range'],axis=1).corrwith(data['Price range']).plot(kind='bar',grid=True,figsize=(20,10),title='Correaltion with Price range')
plt.show()

# %% [markdown]
# **In this plot we can see that column has table booking,aggregate rating and votes are highly correlated to the label and column  cuisines and is delivering now is very least correlated to the label.**

# %%
#Plotting heatmap
corr=data.corr().abs()
plt.figure(figsize=(25,15))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# **In this i dont find any of the feature is multicorrelated with the other.still further i will cross verify it by using VIF method.**

# %%
#making dataset of continuous data 
df=data[['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']]
df
# Out:
#        Longitude   Latitude  Average Cost for two  Aggregate rating  Votes
# 0     121.027535  14.565443                  1100               4.8    314
# 1     121.014101  14.553708                  1200               4.5    591
# 2     121.056831  14.581404                  4000               4.4    270
# 3     121.056475  14.585318                  1500               4.9    365
# 4     121.057508  14.584450                  1500               4.8    229
# ...          ...        ...                   ...               ...    ...
# 9546   28.977392  41.022793                    80               4.1    788
# 9547   29.041297  41.009847                   105               4.2   1034
# 9548   29.034640  41.055817                   170               3.7    661
# 9549   29.036019  41.057979                   120               4.0    901
# 9550   29.026016  40.984776                    55               4.0    591
#
# [9551 rows x 5 columns]

# %%
#plotting box plot
plt.figure(figsize=(5,40))
plotnumber=1
for column in df:
    if plotnumber<=5:
        ax=plt.subplot(6,1,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **In this we can see that outliers are present in all the columns.**

# %%
#Removing outliers
z_score=zscore(data[['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']])
abs_z_score=np.abs(z_score)
threshold=3
z=(abs_z_score<3).all(axis=1)

# %%
data[z].shape
# Out:
# (8756, 17)

# %%
data=data[z]

# %%
#Percentage Loss of Data
data_loss=((9551-8756)/9551)*100
print(f'Data Loss:{data_loss} %')
# Out:
# Data Loss:8.323735734478065 %

# %% [markdown]
# **Since the data loss is more than 7%,thats why not removing the outliers.**

# %%
#checking skewness
data.skew()
# Out:
# Restaurant Name          0.047817
# City                    -1.208515
# Address                 -0.046651
# Locality                -0.267053
# Longitude               -2.804979
# Latitude                -3.124155
# Cuisines                -0.305801
# Average Cost for two     3.619524
# Currency                 2.885278
# Has Table booking        2.382516
# Has Online delivery      1.120081
# Is delivering now       16.505874
# Price range              0.933571
# Aggregate rating        -0.940907
# Rating color             0.047268
# Rating text              0.434638
# Votes                    3.216882
# dtype: float64

# %% [markdown]
# **WE can see that in columns 'Longitude','Latitude','Average Cost for two','Aggregate rating'and 'Votes' skewness is present.so using power transform method to treat the skewness**

# %%
#using power transform method
data[['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']]=power_transform(data[['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']],method='yeo-johnson')
data[['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']]
# Out:
#       Longitude  Latitude  Average Cost for two  Aggregate rating     Votes
# 0      2.499837 -1.619801              1.148984          1.864298  1.302234
# 1      2.499112 -1.621021              1.266904          1.536945  1.656273
# 2      2.501419 -1.618142              3.181609          1.430745  1.218908
# 3      2.501400 -1.617735              1.580936          1.976313  1.385762
# 4      2.501455 -1.617825              1.580936          1.864298  1.128534
# ...         ...       ...                   ...               ...       ...
# 9546  -1.635407  2.271974             -1.448082          1.120993  1.819959
# 9547  -1.633312  2.269582             -1.249657          1.222763  1.976055
# 9548  -1.633530  2.278076             -0.863370          0.728899  1.719768
# 9549  -1.633485  2.278476             -1.147183          1.020715  1.896768
# 9550  -1.633813  2.264952             -1.700169          1.020715  1.656273
#
# [9362 rows x 5 columns]

# %%
#checking skewness
data.skew()
# Out:
# Restaurant Name          0.047817
# City                    -1.208515
# Address                 -0.046651
# Locality                -0.267053
# Longitude               -0.795230
# Latitude                -0.259015
# Cuisines                -0.305801
# Average Cost for two     0.084006
# Currency                 2.885278
# Has Table booking        2.382516
# Has Online delivery      1.120081
# Is delivering now       16.505874
# Price range              0.933571
# Aggregate rating        -0.615772
# Rating color             0.047268
# Rating text              0.434638
# Votes                   -0.021285
# dtype: float64

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['Price range'],axis=1)
#Label
y=data['Price range']

# %%
#Standardiziing the data
#Importing require libraries
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
x_scaler=Scaler.fit_transform(x)
x_scaler
# Out:
# array([[ 0.04602769, -0.23481737,  1.60877727, ..., -2.02241047,
#         -0.45191551,  1.30223393],
#        [-0.22310434, -0.23481737,  0.58435265, ..., -2.02241047,
#         -0.45191551,  1.65627302],
#        [-0.35206344, -0.14820638,  0.05032749, ..., -1.3437794 ,
#          1.932324  ,  1.21890769],
#        ...,
#        [-0.27169762,  2.66665092,  0.54968581, ...,  1.37074487,
#          0.14414437,  1.71976831],
#        [-1.465971  ,  2.66665092,  0.55007532, ..., -1.3437794 ,
#          1.932324  ,  1.8967675 ],
#        [ 1.67717337,  2.66665092, -0.11560592, ..., -1.3437794 ,
#          1.932324  ,  1.65627302]])

# %%
x_scaler.shape
# Out:
# (9362, 16)

# %%
#Importing require libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaler,i)for i in range(x_scaler.shape[1])]
vif['feature']=x.columns
vif
# Out:
#          vif               feature
# 0   1.007141       Restaurant Name
# 1   1.072365                  City
# 2   1.110587               Address
# 3   1.068834              Locality
# 4   1.236021             Longitude
# 5   1.135600              Latitude
# 6   1.040246              Cuisines
# 7   1.897009  Average Cost for two
# 8   1.066435              Currency
# 9   1.515301     Has Table booking
# 10  1.197022   Has Online delivery
# 11  1.014091     Is delivering now
# 12  4.670591      Aggregate rating
# 13  1.221673          Rating color
# 14  1.195436           Rating text
# 15  4.792814                 Votes

# %% [markdown]
# **In this we can see that all the column values are less than 5,so we can say that there is no multicollinearity problem.**

# %%
#importing required libraries
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features=SelectKBest(score_func=f_classif,k=14)
fit=best_features.fit(x_scaler,y)
data_scores=pd.DataFrame(fit.scores_)
data_columns=pd.DataFrame(x.columns)
feature_scores=pd.concat([data_columns,data_scores],axis=1)
feature_scores.columns=['Feature_Name','Score']
print(feature_scores.nlargest(14,'Score'))
# Out:
#             Feature_Name        Score
# 7   Average Cost for two  1530.440440
# 9      Has Table booking  1346.525262
# 15                 Votes  1266.938984
# 12      Aggregate rating   853.438529
# 10   Has Online delivery   260.195219
# 14           Rating text   115.022644
# 3               Locality    64.646673
# 13          Rating color    47.986888
# 1                   City    46.643161
# 5               Latitude    46.632557
# 2                Address    42.909063
# 8               Currency    26.932712
# 0        Restaurant Name    12.949241
# 4              Longitude     9.566102

# %%
new_feature=data[['Average Cost for two','Has Table booking','Votes','Aggregate rating','Has Online delivery','Rating text','Locality','Rating color','City','Latitude','Address','Currency','Restaurant Name','Longitude']]
new_feature
# Out:
#       Average Cost for two  Has Table booking     Votes  Aggregate rating  \
# 0                 1.148984                  1  1.302234          1.864298
# 1                 1.266904                  1  1.656273          1.536945
# 2                 3.181609                  1  1.218908          1.430745
# 3                 1.580936                  0  1.385762          1.976313
# 4                 1.580936                  1  1.128534          1.864298
# ...                    ...                ...       ...               ...
# 9546             -1.448082                  0  1.819959          1.120993
# 9547             -1.249657                  0  1.976055          1.222763
# 9548             -0.863370                  0  1.719768          0.728899
# 9549             -1.147183                  0  1.896768          1.020715
# 9550             -1.700169                  0  1.656273          1.020715
#
#       Has Online delivery  Rating text  Locality  Rating color  City  \
# ...

# %%
#checking whether the label is balance or not
data['Price range'].value_counts()
# Out:
# 1    4437
# 2    3075
# 3    1297
# 4     553
# Name: Price range, dtype: int64

# %% [markdown]
# **So in this we can see data is not balanced,so using smote technique to balance the dataset.**

# %%
#Using oversampling method-Smote method
#importing required libraries
from imblearn.over_sampling import SMOTE

# %%
over_samp=SMOTE()

# %%
x_new,y_new=over_samp.fit_resample(new_feature,y)

# %%
print('The number of classes before fit {}'.format(y.value_counts()))
# Out:
# The number of classes before fit 1    4437
# 2    3075
# 3    1297
# 4     553
# Name: Price range, dtype: int64

# %%
print('The number of classes after fit {}'.format(y_new.value_counts()))
# Out:
# The number of classes after fit 3    4437
# 4    4437
# 2    4437
# 1    4437
# Name: Price range, dtype: int64

# %% [markdown]
# **so we can see that data is balanced.**

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score,plot_roc_curve,f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.svm import SVC

# %% [markdown]
# **Random Forest Classifier**

# %%
#instantiating the model
rfc=RandomForestClassifier()

# %%
#using range fucntion to find the best random state using Random Forest Classifier
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=i)
    rfc.fit(x_train,y_train)
    pred=rfc.predict(x_train)
    y_pred=rfc.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:100.0
# at random state0,the testing accuracy is:96.91232814965066
#
#
# at random state1,the training accuracy is:100.0
# at random state1,the testing accuracy is:95.98828036961912
#
#
# at random state2,the training accuracy is:100.0
# at random state2,the testing accuracy is:96.32634663060627
#
#
# at random state3,the training accuracy is:100.0
# at random state3,the testing accuracy is:96.41649763353617
#
#
# at random state4,the training accuracy is:100.0
# at random state4,the testing accuracy is:95.76290286229434
#
#
# at random state5,the training accuracy is:100.0
# at random state5,the testing accuracy is:96.12350687401397
#
#
# at random state6,the training accuracy is:100.0
# at random state6,the testing accuracy is:96.30380887987378
#
#
# at random state7,the training accuracy is:100.0
# at random state7,the testing accuracy is:96.16858237547893
#
#
# at random state8,the training accuracy is:100.0
# ...

# %% [markdown]
# **Taking random state as 0.**

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=0)

# %%
#Building Model to test unexposed data
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=clf.predict(x_train)
        print('\n=====Train Score=====')
        print(f'Accuracy Score:{accuracy_score(y_train,pred)*100:.2f}%')
    elif train==False:
        y_pred=clf.predict(x_test)
        print('\n=====Test Score=====')
        print(f'Accuracy Score:{accuracy_score(y_test,y_pred)*100:.2f}%')
        print('\n Test Classification Report:\n',classification_report(y_test,y_pred,digits=2))
        print('\n Confusion Matrix:\n',confusion_matrix(y_test,y_pred))
        print('\n F1 Score:\n',f1_score(y_test,y_pred,average='micro'))

# %%
#Training the data
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:96.82%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1089
#            2       0.98      0.96      0.97      1090
#            3       0.94      0.95      0.95      1143
#            4       0.96      0.97      0.96      1115
#
#     accuracy                           0.97      4437
#    macro avg       0.97      0.97      0.97      4437
# weighted avg       0.97      0.97      0.97      4437
#
#
#  Confusion Matrix:
#  [[1081    7    1    0]
#  [   4 1048   34    4]
#  [   1   13 1083   46]
#  [   0    0   31 1084]]
#
#  F1 Score:
#  0.9682217714672076

# %%
#Checking Cross Validation score
#Importing required libraries
from sklearn.model_selection import cross_val_score

# %%
y_pred=rfc.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(rfc,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.8800991661032229and accuracy for the testing is 0.9682217714672076
#
#
# at cross fold 3 the cv score is0.8961573135001126and accuracy for the testing is 0.9682217714672076
#
#
# at cross fold 4 the cv score is0.9066937119675457and accuracy for the testing is 0.9682217714672076
#
#
# at cross fold 5 the cv score is0.9090076236511774and accuracy for the testing is 0.9682217714672076

# %% [markdown]
# **Taking cv=5.**

# %%
#plotting roc curve
fprate,tprate,threshold=roc_curve(y_test,y_pred,pos_label=1)

# %%
print('FPR',fprate)
print('TPR',tprate)
print('Threshold',threshold)
# Out:
# FPR [0.         0.33870968 0.68160096 0.99850657 1.        ]
# TPR [0.00000000e+00 0.00000000e+00 9.18273646e-04 7.34618916e-03
#  1.00000000e+00]
# Threshold [5 4 3 2 1]

# %%
plt.plot(fprate,tprate,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Support vector Machine**

# %%
#instantiatiating the model
svm=SVC()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=0)

# %%
#Training the data
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
#calling the function and passing the dataset for gradient boosting
metric_score(svm,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(svm,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:34.19%
#
# =====Test Score=====
# Accuracy Score:35.00%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.35      0.31      0.33      1089
#            2       0.30      0.18      0.23      1090
#            3       0.36      0.44      0.39      1143
#            4       0.36      0.46      0.41      1115
#
#     accuracy                           0.35      4437
#    macro avg       0.34      0.35      0.34      4437
# weighted avg       0.34      0.35      0.34      4437
#
#
#  Confusion Matrix:
#  [[339 173 271 306]
#  [250 198 318 324]
#  [197 164 498 284]
#  [172 115 310 518]]
#
#  F1 Score:
#  0.35001126887536627

# %%
#Checking cross validation score
cv_score=cross_val_score(svm,x_new,y_new,cv=5).mean()
cv_score
# Out:
# 0.31288448640561317

# %%
#plotting roc curve
fprate,tprate,threshold=roc_curve(y_test,y_pred,pos_label=1)

# %%
print('FPR',fprate)
print('TPR',tprate)
print('Threshold',threshold)
# Out:
# FPR [0.         0.33870968 0.68160096 0.99850657 1.        ]
# TPR [0.00000000e+00 0.00000000e+00 9.18273646e-04 7.34618916e-03
#  1.00000000e+00]
# Threshold [5 4 3 2 1]

# %%
plt.plot(fprate,tprate,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Ada Boost Classifier**

# %%
#Initiating Ada boost classifier
ada=AdaBoostClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=0)

# %%
#Training the data
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
#calling the function and passing the dataset for ada boost
metric_score(ada,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(ada,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:58.70%
#
# =====Test Score=====
# Accuracy Score:58.37%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.96      0.98      1089
#            2       0.46      0.80      0.59      1090
#            3       0.41      0.21      0.28      1143
#            4       0.47      0.38      0.42      1115
#
#     accuracy                           0.58      4437
#    macro avg       0.58      0.59      0.57      4437
# weighted avg       0.58      0.58      0.56      4437
#
#
#  Confusion Matrix:
#  [[1047   42    0    0]
#  [   6  873   36  175]
#  [   0  593  243  307]
#  [   0  377  311  427]]
#
#  F1 Score:
#  0.5837277439711517

# %%
#Checking cross validation score
cv_score=cross_val_score(ada,x_new,y_new,cv=5).mean()
cv_score
# Out:
# 0.5562910560006985

# %%
#plotting roc curve
fprate,tprate,threshold=roc_curve(y_test,y_pred,pos_label=1)

# %%
print('FPR',fprate)
print('TPR',tprate)
print('Threshold',threshold)
# Out:
# FPR [0.         0.33870968 0.68160096 0.99850657 1.        ]
# TPR [0.00000000e+00 0.00000000e+00 9.18273646e-04 7.34618916e-03
#  1.00000000e+00]
# Threshold [5 4 3 2 1]

# %%
plt.plot(fprate,tprate,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **DECISIONTREE CLASSIFIER**

# %%
#Instantiating the models
dt=DecisionTreeClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=0)

# %%
#Training the data
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(dt,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(dt,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:94.16%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1089
#            2       0.96      0.96      0.96      1090
#            3       0.90      0.89      0.90      1143
#            4       0.91      0.92      0.92      1115
#
#     accuracy                           0.94      4437
#    macro avg       0.94      0.94      0.94      4437
# weighted avg       0.94      0.94      0.94      4437
#
#
#  Confusion Matrix:
#  [[1084    3    1    1]
#  [   1 1045   37    7]
#  [   2   32 1021   88]
#  [   3    7   77 1028]]
#
#  F1 Score:
#  0.9416272256028848

# %%
#Checking cross validation score
cv_score=cross_val_score(dt,x_new,y_new,cv=5).mean()
cv_score
# Out:
# 0.8828066465856281

# %%
#plotting roc curve
fprate,tprate,threshold=roc_curve(y_test,y_pred,pos_label=1)

# %%
print('FPR',fprate)
print('TPR',tprate)
print('Threshold',threshold)
# Out:
# FPR [0.         0.33870968 0.68160096 0.99850657 1.        ]
# TPR [0.00000000e+00 0.00000000e+00 9.18273646e-04 7.34618916e-03
#  1.00000000e+00]
# Threshold [5 4 3 2 1]

# %%
plt.plot(fprate,tprate,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['Random Forest','SVM','Ada Boost','Decision Tree'],
    'Training Score':[100,34.19,58.70,100],
    'Testing Score':[96.82,35.00,58.37,94.16],
    'Cross Val Score':[90.90,31.28,55.62,88.28],
    'F1 score':[96.82,35.00,58.37,94.16]
})
data
# Out:
#           Models  Training Score  Testing Score  Cross Val Score  F1 score
# 0  Random Forest          100.00          96.82            90.90     96.82
# 1            SVM           34.19          35.00            31.28     35.00
# 2      Ada Boost           58.70          58.37            55.62     58.37
# 3  Decision Tree          100.00          94.16            88.28     94.16

# %% [markdown]
# **Observation**
# * **In this we can see that Random forest and decision tree model have seen most of the data that is 100%, but testing score of random forest is higher than decsion tress that is 96.82% and cross validation score and f1-score are close to testing score.**
# * **Because of this i am going forward with Random Forest.**

# %%
#Using Grid Search cv for hyperparameter tuning for Random Forest
from sklearn.model_selection import GridSearchCV

# %%
param_grid=({
    'n_estimators': [100,150],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [2,3,4],
    'criterion' :['gini', 'entropy']
})

# %%
grid_search=GridSearchCV(rfc,param_grid=param_grid,cv=5)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 150]})

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'n_estimators': 150}

# %%
#Training with the best parameters
rfc1=RandomForestClassifier(criterion='entropy',max_depth=4,max_features='log2',n_estimators=150)
rfc1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=4, max_features='log2',
#                        n_estimators=150)

# %%
#calling the function and passing the dataset
metric_score(rfc1,x_train,x_test,y_train,y_test,train=True)#Training Score
metric_score(rfc1,x_train,x_test,y_train,y_test,train=False)#Testing Score
# Out:
# =====Train Score=====
# Accuracy Score:84.34%
#
# =====Test Score=====
# Accuracy Score:84.36%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.95      0.97      1089
#            2       0.88      0.87      0.87      1090
#            3       0.79      0.68      0.73      1143
#            4       0.75      0.88      0.81      1115
#
#     accuracy                           0.84      4437
#    macro avg       0.85      0.85      0.84      4437
# weighted avg       0.85      0.84      0.84      4437
#
#
#  Confusion Matrix:
#  [[1039   12   29    9]
#  [  10  953   73   54]
#  [   1   99  775  268]
#  [   4   25  110  976]]
#
#  F1 Score:
#  0.8435880099166103

# %%
#Checking cross validation score
cv_score=cross_val_score(rfc1,x_new,y_new,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.828488691517944

# %% [markdown]
# **In this we can see that after using hyperparameter tuning training testing cross validation and f1-score have been reduced.so further i am saving Random Forest model on which hyperparameter was not done.**

# %%
y_pred_prob=rfc.predict_proba(x_test)

# %%
#Checking AUC Score
roc_auc_score=roc_auc_score(y_test,y_pred_prob,multi_class='ovr')
roc_auc_score
# Out:
# 0.9982815495606754

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(rfc,open('Zomato Restaurant Classifier Project','wb'))
